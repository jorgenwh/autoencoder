# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
from keras.datasets import mnist
# Out:
# 2024-01-26 11:39:00.199228: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-26 11:39:00.226711: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-26 11:39:00.226732: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-26 11:39:00.227401: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-26 11:39:00.232058: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-26 11:39:00.849709: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from models import MLPAutoEncoder, ConvAutoEncoder

# %%
(x_train, _), (_, _) = mnist.load_data()
x_train = x_train.astype('float32') / 255.0

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 20
BATCH_SIZE = 128
LEARNING_RATE = 0.005

# train an MLP autoencoder on MNIST
mlp_model = MLPAutoEncoder(input_dim=784, latent_dim=3).to(DEVICE)
optimizer = torch.optim.Adam(mlp_model.parameters(), lr=LEARNING_RATE)
criterion = torch.nn.MSELoss()
inspections = []

for epoch in range(EPOCHS):
    print("Epoch: " + str(epoch + 1) + "/" + str(EPOCHS))
    epoch_loss = 0
    updates = 0

    for i in range(0, len(x_train), BATCH_SIZE):
        batch = x_train[i:i + BATCH_SIZE].reshape(-1, 784)
        batch = torch.from_numpy(batch).to(DEVICE)

        # forward pass
        output = mlp_model(batch)
        loss = criterion(output, batch)

        epoch_loss += loss.item()

        # backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        updates += 1

        print(
            "update: " + str(updates) + "/" + str(len(x_train)//BATCH_SIZE + 1) + " | " +
            "loss: " + str(round(epoch_loss/updates, 5)), end="\r")

    print(
        "update: " + str(updates) + "/" + str(len(x_train)//BATCH_SIZE + 1) + " | " +
        "loss: " + str(round(epoch_loss/updates, 5)))

    if (epoch % 2 == 0 and len(inspections) < 4) or epoch == EPOCHS - 1:
        inspections.append((
            epoch, 
            batch.to("cpu").detach().numpy(), 
            output.to("cpu").detach().numpy()
        ))
# Out:
# Epoch: 1/20
# update: 469/469 | loss: 0.06104
# Epoch: 2/20
# update: 469/469 | loss: 0.05504
# Epoch: 3/20
# update: 469/469 | loss: 0.05241
# Epoch: 4/20
# update: 469/469 | loss: 0.05126
# Epoch: 5/20
# update: 469/469 | loss: 0.05052
# Epoch: 6/20
# update: 469/469 | loss: 0.04995
# Epoch: 7/20
# update: 469/469 | loss: 0.04938
# Epoch: 8/20
# update: 469/469 | loss: 0.04905
# Epoch: 9/20
# update: 469/469 | loss: 0.04859
# Epoch: 10/20
# update: 469/469 | loss: 0.04819
# Epoch: 11/20
# update: 469/469 | loss: 0.04802
# Epoch: 12/20
# update: 469/469 | loss: 0.04736
# Epoch: 13/20
# update: 469/469 | loss: 0.04715
# Epoch: 14/20
# update: 469/469 | loss: 0.04703
# Epoch: 15/20
# update: 469/469 | loss: 0.04682
# Epoch: 16/20
# update: 469/469 | loss: 0.04672
# Epoch: 17/20
# update: 469/469 | loss: 0.04644
# Epoch: 18/20
# update: 469/469 | loss: 0.04625
# Epoch: 19/20
# update: 469/469 | loss: 0.04627
# Epoch: 20/20
# update: 469/469 | loss: 0.04634

# %%
# examine how proficient the MLP autoencoder is at reconstructing over epochs
for epoch, imgs, recons in inspections:
    plt.figure(figsize=(9, 2))
    plt.title("Epoch " + str(epoch + 1))
    plt.gray()
    for i, img in enumerate(imgs[:9]):
        plt.subplot(2, 9, i+1)
        plt.imshow(img.reshape(28, 28))
    for i, recon in enumerate(recons[:9]):
        plt.subplot(2, 9, 9+i+1)
        plt.imshow(recon.reshape(28, 28))

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
EPOCHS = 20
BATCH_SIZE = 128
LEARNING_RATE = 0.005

# train a convolutional autoencoder on MNIST
mlp_model = ConvAutoEncoder().to(DEVICE)
optimizer = torch.optim.Adam(mlp_model.parameters(), lr=LEARNING_RATE)
criterion = torch.nn.MSELoss()
inspections = []

for epoch in range(EPOCHS):
    print("Epoch: " + str(epoch + 1) + "/" + str(EPOCHS))
    epoch_loss = 0
    updates = 0

    for i in range(0, len(x_train), BATCH_SIZE):
        batch = x_train[i:i + BATCH_SIZE].reshape(-1, 1, 28, 28)
        batch = torch.from_numpy(batch).to(DEVICE)

        # forward pass
        output = mlp_model(batch)
        loss = criterion(output, batch)

        epoch_loss += loss.item()

        # backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        updates += 1

        print(
            "update: " + str(updates) + "/" + str(len(x_train)//BATCH_SIZE + 1) + " | " +
            "loss: " + str(round(epoch_loss/updates, 5)), end="\r")

    print(
        "update: " + str(updates) + "/" + str(len(x_train)//BATCH_SIZE + 1) + " | " +
        "loss: " + str(round(epoch_loss/updates, 5)))

    if (epoch % 2 == 0 and len(inspections) < 4) or epoch == EPOCHS - 1:
        inspections.append((
            epoch, 
            batch.to("cpu").detach().numpy(), 
            output.to("cpu").detach().numpy()
        ))
# Out:
# Epoch: 1/20
# update: 469/469 | loss: 0.02647
# Epoch: 2/20
# update: 469/469 | loss: 0.00601
# Epoch: 3/20
# update: 469/469 | loss: 0.00461
# Epoch: 4/20
# update: 469/469 | loss: 0.00403
# Epoch: 5/20
# update: 469/469 | loss: 0.00364
# Epoch: 6/20
# update: 469/469 | loss: 0.00338
# Epoch: 7/20
# update: 469/469 | loss: 0.00321
# Epoch: 8/20
# update: 469/469 | loss: 0.00313
# Epoch: 9/20
# update: 469/469 | loss: 0.00302
# Epoch: 10/20
# update: 469/469 | loss: 0.00293
# Epoch: 11/20
# update: 469/469 | loss: 0.00288
# Epoch: 12/20
# update: 469/469 | loss: 0.00289
# Epoch: 13/20
# update: 469/469 | loss: 0.00279
# Epoch: 14/20
# update: 469/469 | loss: 0.00274
# Epoch: 15/20
# update: 469/469 | loss: 0.00272
# Epoch: 16/20
# update: 469/469 | loss: 0.00265
# Epoch: 17/20
# update: 469/469 | loss: 0.00261
# Epoch: 18/20
# update: 469/469 | loss: 0.00261
# Epoch: 19/20
# update: 469/469 | loss: 0.00257
# Epoch: 20/20
# update: 469/469 | loss: 0.00252

# %%
# examine how proficient the convolutional autoencoder is at reconstructing over epochs
for epoch, imgs, recons in inspections:
    plt.figure(figsize=(9, 2))
    plt.title("Epoch " + str(epoch + 1))
    plt.gray()
    for i, img in enumerate(imgs[:9]):
        plt.subplot(2, 9, i+1)
        plt.imshow(img.reshape(28, 28))
    for i, recon in enumerate(recons[:9]):
        plt.subplot(2, 9, 9+i+1)
        plt.imshow(recon.reshape(28, 28))
